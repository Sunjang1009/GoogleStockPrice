# %%
import datetime
from datetime import datetime, date
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
pd.set_option('display.notebook_repr_html', True)
pd.set_option('display.max_columns', 7)
pd.set_option('display.max_rows', 10)
pd.set_option('display.width', 250)
# %matplotlib inline
import os 
import json  
import re
from re import match, findall, sub

# %%
df = pd.read_csv("C:/Users/sunja/OneDrive/Desktop/SunJang/PyCode/GitHub/data/Google_Stock_Price_Test.csv",index_col="Date")
df2 = df[['High','Low']]
df2.plot(kind='line',title='Google Stock Price High Low')
plt.show()
